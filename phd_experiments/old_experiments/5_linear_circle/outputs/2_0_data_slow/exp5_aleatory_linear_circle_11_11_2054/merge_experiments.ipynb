# %%
import pandas as pd

# Leer los dos archivos CSV en DataFrames
df1 = pd.read_csv('data_5000.csv')
df2 = pd.read_csv('data_8700.csv')

# Eliminar el último elemento del DataFrame
df1 = df1.iloc[:-1]

df1.keys()
# Out:
# Index(['i_sample', 'n_local_networks', 'n_var_network', 'v_topology',
#        'n_output_variables', 'n_clauses_function', 'n_local_attractors',
#        'n_pair_attractors', 'n_attractor_fields', 'n_time_find_attractors',
#        'n_time_find_pairs', 'n_time_find_fields'],
#       dtype='object')

# %%
df2.tail()
# Out:
#       i_sample  n_local_networks  n_var_network  v_topology  \
# 1491       746                11              5           3
# 1492       747                11              5           4
# 1493       747                11              5           3
# 1494       748                11              5           4
# 1495       748                11              5           3
#
#       n_output_variables  n_clauses_function  n_local_attractors  \
# 1491                   2                   2                  44
# 1492                   2                   2                  22
# 1493                   2                   2                  22
# 1494                   2                   2                  96
# 1495                   2                   2                  99
#
#       n_pair_attractors  n_attractor_fields  n_time_find_attractors  \
# 1491                 88                2048                1.696437
# 1492                 19                   1                1.418633
# 1493                 22                   1                1.415848
# 1494                522           362797056                2.752111
# 1495                594           362797056                2.939826
#
#       n_time_find_pairs  n_time_find_fields
# 1491           0.000491            0.380688
# 1492           0.000556            0.000267
# 1493           0.000633            0.000450
# 1494           0.000902        18099.684891
# 1495           0.001390       216311.376180

# %%
# Calcular el desplazamiento para el índice del segundo DataFrame
desplazamiento = df1['i_sample'].iloc[-1]

# Agregar el desplazamiento al índice del segundo DataFrame
df2['i_sample'] += desplazamiento

# Calcular el desplazamiento para el índice del segundo DataFrame
desplazamiento = df2['i_sample'].iloc[-1]

# Concatenar los dos DataFrames
df = pd.concat([df1, df2])

# Restablecer el índice si es necesario
df.reset_index(drop=True, inplace=True)

# Mostrar el DataFrame resultante
df.tail(10)
# Out:
#       i_sample  n_local_networks  n_var_network  v_topology  \
# 4098      2050                11              5           4
# 4099      2050                11              5           3
# 4100      2051                11              5           4
# 4101      2051                11              5           3
# 4102      2052                11              5           4
# 4103      2052                11              5           3
# 4104      2053                11              5           4
# 4105      2053                11              5           3
# 4106      2054                11              5           4
# 4107      2054                11              5           3
#
#       n_output_variables  n_clauses_function  n_local_attractors  \
# 4098                   2                   2                  21
# 4099                   2                   2                  22
# 4100                   2                   2                  21
# 4101                   2                   2                  22
# 4102                   2                   2                  42
# 4103                   2                   2                  44
# 4104                   2                   2                  22
# 4105                   2                   2                  22
# 4106                   2                   2                  96
# 4107                   2                   2                  99
#
#       n_pair_attractors  n_attractor_fields  n_time_find_attractors  \
# 4098                 19                   1                1.189134
# 4099                 22                   1                1.234573
# 4100                 19                   1                1.164446
# 4101                 22                   1                1.294379
# 4102                 76                2048                1.624584
# 4103                 88                2048                1.696437
# 4104                 19                   1                1.418633
# 4105                 22                   1                1.415848
# 4106                522           362797056                2.752111
# 4107                594           362797056                2.939826
#
#       n_time_find_pairs  n_time_find_fields
# 4098           0.000573            0.000292
# 4099           0.000484            0.000329
# 4100           0.000543            0.000257
# 4101           0.000680            0.000468
# 4102           0.000439            0.087512
# 4103           0.000491            0.380688
# 4104           0.000556            0.000267
# 4105           0.000633            0.000450
# 4106           0.000902        18099.684891
# 4107           0.001390       216311.376180

# %%
# Guardar el DataFrame en un archivo CSV
df.to_csv('data.csv', index=False)
