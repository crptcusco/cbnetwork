# %% [markdown]
# # Example Aleatory Complete CBN

# %%
# import libraries
from cbnetwork.cbnetwork import CBN
from cbnetwork.globaltopology import GlobalTopology

# List of the Allowed Topologies
GlobalTopology.show_allowed_topologies()
# Out:
# ==================================================
# LIST OF ALLOWED TOPOLOGIES
# 1 - complete_graph
# 2 - binomial_tree
# 3 - cycle_graph
# 4 - path_graph
# 5 - gn_graph
# 6 - gnc_graph
# 7 - linear_graph
# 8 - aleatory_digraph

# %% [markdown]
# # Generate a CBN with the parameters

# %%
# pass the parameters
n_local_networks = 6
n_var_network = 5
n_output_variables = 2
n_clauses_function = 2
v_topology = 1

o_cbn = CBN.generate_cbn(n_local_networks=n_local_networks, n_var_network=n_var_network, v_topology=v_topology,
                         n_output_variables=n_output_variables, n_clauses_function=n_clauses_function)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 8
#       5 n_clauses_function = 2
#       6 v_topology = 1
# ----> 8 o_cbn = CBN.generate_cbn(n_local_networks=n_local_networks, n_var_network=n_var_network, v_topology=v_topology,
#       9                          n_output_variables=n_output_variables, n_clauses_function=n_clauses_function)
#
# AttributeError: type object 'CBN' has no attribute 'generate_cbn'

# %% [markdown]
# # Find local network attractors

# %%
o_cbn.find_local_attractors_optimized()

# %% [markdown]
# # find the compatible pairs

# %%
o_cbn.find_compatible_pairs()

# %%
o_cbn.show_cbn_graph()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 o_cbn.show_cbn_graph()
#
# NameError: name 'o_cbn' is not defined

# %%
o_cbn.show_attractors()

# %%
o_cbn.show_coupled_signals_kind()

# %%
# find the compatible pairs
o_cbn.find_compatible_pairs()
o_cbn.show_attractor_pairs()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # find the compatible pairs
# ----> 2 o_cbn.find_compatible_pairs()
#       3 o_cbn.show_attractor_pairs()
#
# NameError: name 'o_cbn' is not defined

# %%
# Find attractor fields
o_cbn.find_attractor_fields()
o_cbn.show_attractors_fields()
#
