# %% [markdown]
# # All Allowed Topologies by GlobalTopology

# %%
from classes.globaltopology import GlobalTopology

GlobalTopology.show_allowed_topologies()
# Out:
# ...
# LIST OF ALLOWED TOPOLOGIES OF DIRECTED GRAPHS
# 1 - complete
# 2 - aleatory_fixed_2_input_edges
# 3 - cycle
# 4 - path
# 5 - aleatory_gn
# 6 - aleatory_gnc
# 7 - dorogovtsev_mendes
# 8 - small_world
# 9 - scale_free
# 10 - random

# %% [markdown]
# ## Complete Directed Graph

# %%
N_NODES = 6
N_EDGES = None
V_TOPOLOGY = 1

o_global_topology = GlobalTopology.generate_sample_topology(v_topology=V_TOPOLOGY, n_nodes=N_NODES, n_edges=N_EDGES)
o_global_topology.plot_topology()
type(o_global_topology)
# Out:
# classes.globaltopology.CompleteDigraph

# %% [markdown]
# ## Fixed Aleatory Directed Graph

# %%
N_NODES = 6
V_TOPOLOGY = 2

o_global_topology = GlobalTopology.generate_sample_topology(v_topology=V_TOPOLOGY, n_nodes=N_NODES)
o_global_topology.plot_topology()
type(o_global_topology)
# Out:
# classes.globaltopology.AleatoryFixedDigraph

# %% [markdown]
# # Circular Directed Graph

# %%
N_NODES = 6
V_TOPOLOGY = 3

o_global_topology = GlobalTopology.generate_sample_topology(v_topology=V_TOPOLOGY, n_nodes=N_NODES)
o_global_topology.plot_topology()
type(o_global_topology)
# Out:
# classes.globaltopology.CycleDigraph

# %% [markdown]
# # Linear Directed Graph (Path)

# %%
N_NODES = 6
V_TOPOLOGY = 4

o_global_topology = GlobalTopology.generate_sample_topology(v_topology=V_TOPOLOGY, n_nodes=N_NODES)
o_global_topology.plot_topology()
type(o_global_topology)
# Out:
# classes.globaltopology.PathDigraph

# %%
N_NODES = 6
V_TOPOLOGY = 7

o_global_topology = GlobalTopology.generate_sample_topology(v_topology=V_TOPOLOGY, n_nodes=N_NODES)
o_global_topology.plot_topology()
type(o_global_topology)
# Out:
# classes.globaltopology.DorogovtsevMendesDigraph

# %%
N_NODES = 6
V_TOPOLOGY = 8

o_global_topology = GlobalTopology.generate_sample_topology(v_topology=V_TOPOLOGY, n_nodes=N_NODES)
o_global_topology.plot_topology()
type(o_global_topology)
# Out:
# classes.globaltopology.SmallWorldGraph

# %%
N_NODES = 6
V_TOPOLOGY = 9

o_global_topology = GlobalTopology.generate_sample_topology(v_topology=V_TOPOLOGY, n_nodes=N_NODES)
o_global_topology.plot_topology()
type(o_global_topology)
# Out:
# classes.globaltopology.ScaleFreeGraph

# %%
N_NODES = 6
V_TOPOLOGY = 10

o_global_topology = GlobalTopology.generate_sample_topology(v_topology=V_TOPOLOGY, n_nodes=N_NODES)
o_global_topology.plot_topology()
type(o_global_topology)
# Out:
# classes.globaltopology.RandomGraph
