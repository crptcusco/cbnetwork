# %%
from cbnetwork.globaltopology import GlobalTopology

N_NODES = 6
N_EDGES = 6
V_TOPOLOGY = 2

o_global_topology = GlobalTopology.generate_sample_topology(v_topology=V_TOPOLOGY, n_nodes=N_NODES, n_edges=N_EDGES)

o_global_topology.plot_topology()
print(type(o_global_topology))
# Out:
# <class 'cbnetwork.globaltopology.AleatoryFixedDigraph'>

# %%
o_global_topology.add_node()
o_global_topology.plot_topology()
# Out:
# 2026-01-15 16:24:59,531 INFO:cbnetwork.globaltopology:Adding new node: 7
# 2026-01-15 16:24:59,533 INFO:cbnetwork.globaltopology:Removed edge: (1, 2)
# 2026-01-15 16:24:59,534 INFO:cbnetwork.globaltopology:Added edge from 5 to 7
# 2026-01-15 16:24:59,534 INFO:cbnetwork.globaltopology:Added edge from 7 to 2
# 2026-01-15 16:24:59,535 INFO:cbnetwork.globaltopology:Ensured connectivity by adding edge from 7 to 1
# 2026-01-15 16:24:59,536 INFO:cbnetwork.globaltopology:Node 7 added in 0.004143953323364258 seconds

# %%
o_global_topology.generate_edge()
o_global_topology.plot_topology()
