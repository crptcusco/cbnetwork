# %%
from cbnetwork.globaltopology import GlobalTopology

# Parameters
n_local_networks = 3
v_topology = 4

# generate the CBN topology object
o_global_topology = GlobalTopology.generate_sample_topology(v_topology=v_topology, n_nodes=n_local_networks)
o_global_topology.plot_topology()

# %%
o_global_topology.add_node()
o_global_topology.plot_topology()

# %%
o_global_topology.add_node()
o_global_topology.plot_topology()
