# %% [markdown]
# # CBN ALEATORY EXAMPLE

# %%
# import libraries
from classes.cbnetwork import CBN

# %%
CBN.show_allowed_topologies()
# Out:
# INFO: 1 - complete_graph
# INFO: 2 - binomial_tree
# INFO: 3 - cycle_graph
# INFO: 4 - path_graph
# INFO: 5 - gn_graph
# INFO: 6 - gnc_graph
# INFO: 7 - linear_graph

# %% [markdown]
# # Generating the CBN

# %%
# pass the parameters
n_local_networks = 10
n_var_network = 5
n_output_variables = 2
n_clauses_function = 2
v_topology = 6

# create a Coupled Boolean Network with the parameters
o_cbn = CBN.generate_cbn(n_local_networks=n_local_networks, n_var_network=n_var_network, v_topology=v_topology,
                         n_output_variables=n_output_variables, n_clauses_function=n_clauses_function)
# Out:
# MESSAGE: Generating the CBN
# ==================
# MESSAGE: Local network created : 1
# ---------------------
# MESSAGE: Local network created : 2
# ---------------------
# MESSAGE: Local network created : 3
# ---------------------
# MESSAGE: Local network created : 4
# ---------------------
# MESSAGE: Local network created : 5
# ---------------------
# MESSAGE: Local network created : 6
# ---------------------
# MESSAGE: Local network created : 7
# ---------------------
# MESSAGE: Local network created : 8
# ---------------------
# MESSAGE: Local network created : 9
# ---------------------
# MESSAGE: Local network created : 10
# ---------------------
# MESSAGE: Coupled Boolean Network created
# ===============================

# %%
o_cbn.show_cbn_graph()

# %%
# find local network attractors
o_cbn.find_attractors()

# find the compatible pairs
o_cbn.find_compatible_pairs()

# show the kind of every coupled signal
o_cbn.show_coupled_signals_kind()

# find attractors fields
# o_cbn.find_attractor_fields()

# # show graph with networkx
# o_cbn.generate_graph()

# # show attractors
# o_cbn.show_attractors()

# Show attractor fields
# o_cbn.show_attractors_fields()
# Out:
# ==================================================
# MESSAGE: FIND ATTRACTORS USING OPTIMIZED METHOD
# -------------------------------------
# MESSAGE: Begin of the initial loop
# MESSAGE: NETWORK NUMBER :  6  PERMUTATION SIGNAL COUPLING:  None
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: the attractor signal value is stable
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# MESSAGE: the output signal is stable
# MESSAGE: the attractor signal value is stable
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# MESSAGE: the output signal is stable
# MESSAGE: INITIAL HEAP
# [6, 8, 7, 9, 10, 2, 3, 1, 4, 5]
# MESSAGE: UPDATE HEAP
# [7, 8, 3, 9, 10, 2, 5, 1, 4]
# MESSAGE: NETWORK NUMBER :  7  PERMUTATION SIGNAL COUPLING:  None
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# INFO: Local Network: 7 Weight: 0
# INFO: Local network: 7
# INFO: Index variable output signal: 56
# INFO: Output variables: [33, 32]
# {'11': '1', '10': '1', '01': '1', '00': '0'}
# INFO: Scene:  None
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [31, 32, 33, 34, 35]
# INFO: [31, 32, 33, 34, 35]
# INFO: ['0', '0', '0', '0', '0']
# INFO: Variables list: [31, 32, 33, 34, 35]
# INFO: Output variables list: [33, 32]
# INFO: Output variable: 33
# INFO: Variables list: [31, 32, 33, 34, 35]
# INFO: Output variables list: [33, 32]
# INFO: Output variable: 32
# INFO: [33, 32]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [31, 32, 33, 34, 35]
# INFO: [31, 32, 33, 34, 35]
# INFO: ['1', '1', '1', '1', '1']
# INFO: Variables list: [31, 32, 33, 34, 35]
# INFO: Output variables list: [33, 32]
# INFO: Output variable: 33
# INFO: Variables list: [31, 32, 33, 34, 35]
# INFO: Output variables list: [33, 32]
# INFO: Output variable: 32
# INFO: [33, 32]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [31, 32, 33, 34, 35]
# INFO: [31, 32, 33, 34, 35]
# INFO: ['0', '0', '1', '0', '0']
# INFO: Variables list: [31, 32, 33, 34, 35]
# INFO: Output variables list: [33, 32]
# INFO: Output variable: 33
# INFO: Variables list: [31, 32, 33, 34, 35]
# INFO: Output variables list: [33, 32]
# INFO: Output variable: 32
# INFO: [33, 32]
# INFO: 10
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [31, 32, 33, 34, 35]
# INFO: [31, 32, 33, 34, 35]
# INFO: ['1', '0', '1', '0', '0']
# INFO: Variables list: [31, 32, 33, 34, 35]
# INFO: Output variables list: [33, 32]
# INFO: Output variable: 33
# INFO: Variables list: [31, 32, 33, 34, 35]
# INFO: Output variables list: [33, 32]
# INFO: Output variable: 32
# INFO: [33, 32]
# INFO: 10
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# MESSAGE: the output signal is stable
# ===============================
# INFO: RESUME
# MESSAGE: The Local attractors are computed
# MESSAGE: NETWORK NUMBER :  8  PERMUTATION SIGNAL COUPLING:  None
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# INFO: Local Network: 8 Weight: 0
# INFO: Local network: 8
# INFO: Index variable output signal: 57
# INFO: Output variables: [38, 40]
# {'11': '1', '10': '1', '01': '1', '00': '0'}
# INFO: Scene:  None
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [36, 37, 38, 39, 40]
# INFO: [36, 37, 38, 39, 40]
# INFO: ['0', '0', '0', '0', '0']
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [38, 40]
# INFO: Output variable: 38
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [38, 40]
# INFO: Output variable: 40
# INFO: [38, 40]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [36, 37, 38, 39, 40]
# INFO: [36, 37, 38, 39, 40]
# INFO: ['1', '1', '1', '1', '0']
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [38, 40]
# INFO: Output variable: 38
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [38, 40]
# INFO: Output variable: 40
# INFO: [38, 40]
# INFO: 10
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [36, 37, 38, 39, 40]
# INFO: [36, 37, 38, 39, 40]
# INFO: ['1', '0', '1', '1', '0']
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [38, 40]
# INFO: Output variable: 38
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [38, 40]
# INFO: Output variable: 40
# INFO: [38, 40]
# INFO: 10
# INFO: Output value : 1
# INFO: STATE
# INFO: [36, 37, 38, 39, 40]
# INFO: [36, 37, 38, 39, 40]
# INFO: ['1', '1', '1', '0', '0']
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [38, 40]
# INFO: Output variable: 38
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [38, 40]
# INFO: Output variable: 40
# INFO: [38, 40]
# INFO: 10
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [36, 37, 38, 39, 40]
# INFO: [36, 37, 38, 39, 40]
# INFO: ['0', '0', '1', '0', '0']
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [38, 40]
# INFO: Output variable: 38
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [38, 40]
# INFO: Output variable: 40
# INFO: [38, 40]
# INFO: 10
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [36, 37, 38, 39, 40]
# INFO: [36, 37, 38, 39, 40]
# INFO: ['1', '1', '1', '1', '1']
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [38, 40]
# INFO: Output variable: 38
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [38, 40]
# INFO: Output variable: 40
# INFO: [38, 40]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# MESSAGE: the output signal is stable
# INFO: Index variable output signal: 61
# INFO: Output variables: [37, 39]
# {'11': '1', '10': '1', '01': '1', '00': '0'}
# INFO: Scene:  None
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [36, 37, 38, 39, 40]
# INFO: [36, 37, 38, 39, 40]
# INFO: ['0', '0', '0', '0', '0']
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [37, 39]
# INFO: Output variable: 37
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [37, 39]
# INFO: Output variable: 39
# INFO: [37, 39]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [36, 37, 38, 39, 40]
# INFO: [36, 37, 38, 39, 40]
# INFO: ['1', '1', '1', '1', '0']
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [37, 39]
# INFO: Output variable: 37
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [37, 39]
# INFO: Output variable: 39
# INFO: [37, 39]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [36, 37, 38, 39, 40]
# INFO: [36, 37, 38, 39, 40]
# INFO: ['1', '0', '1', '1', '0']
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [37, 39]
# INFO: Output variable: 37
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [37, 39]
# INFO: Output variable: 39
# INFO: [37, 39]
# INFO: 01
# INFO: Output value : 1
# INFO: STATE
# INFO: [36, 37, 38, 39, 40]
# INFO: [36, 37, 38, 39, 40]
# INFO: ['1', '1', '1', '0', '0']
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [37, 39]
# INFO: Output variable: 37
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [37, 39]
# INFO: Output variable: 39
# INFO: [37, 39]
# INFO: 10
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [36, 37, 38, 39, 40]
# INFO: [36, 37, 38, 39, 40]
# INFO: ['0', '0', '1', '0', '0']
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [37, 39]
# INFO: Output variable: 37
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [37, 39]
# INFO: Output variable: 39
# INFO: [37, 39]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [36, 37, 38, 39, 40]
# INFO: [36, 37, 38, 39, 40]
# INFO: ['1', '1', '1', '1', '1']
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [37, 39]
# INFO: Output variable: 37
# INFO: Variables list: [36, 37, 38, 39, 40]
# INFO: Output variables list: [37, 39]
# INFO: Output variable: 39
# INFO: [37, 39]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# MESSAGE: the output signal is stable
# ===============================
# INFO: RESUME
# MESSAGE: The Local attractors are computed
# MESSAGE: NETWORK NUMBER :  10  PERMUTATION SIGNAL COUPLING:  None
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# INFO: Local Network: 10 Weight: 0
# INFO: Local network: 10
# INFO: Index variable output signal: 59
# INFO: Output variables: [48, 47]
# {'11': '1', '10': '1', '01': '1', '00': '0'}
# INFO: Scene:  None
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [46, 47, 48, 49, 50]
# INFO: [46, 47, 48, 49, 50]
# INFO: ['1', '1', '1', '1', '1']
# INFO: Variables list: [46, 47, 48, 49, 50]
# INFO: Output variables list: [48, 47]
# INFO: Output variable: 48
# INFO: Variables list: [46, 47, 48, 49, 50]
# INFO: Output variables list: [48, 47]
# INFO: Output variable: 47
# INFO: [48, 47]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [46, 47, 48, 49, 50]
# INFO: [46, 47, 48, 49, 50]
# INFO: ['0', '0', '0', '0', '0']
# INFO: Variables list: [46, 47, 48, 49, 50]
# INFO: Output variables list: [48, 47]
# INFO: Output variable: 48
# INFO: Variables list: [46, 47, 48, 49, 50]
# INFO: Output variables list: [48, 47]
# INFO: Output variable: 47
# INFO: [48, 47]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# MESSAGE: the output signal is stable
# INFO: Index variable output signal: 62
# INFO: Output variables: [49, 46]
# {'11': '1', '10': '1', '01': '1', '00': '0'}
# INFO: Scene:  None
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [46, 47, 48, 49, 50]
# INFO: [46, 47, 48, 49, 50]
# INFO: ['1', '1', '1', '1', '1']
# INFO: Variables list: [46, 47, 48, 49, 50]
# INFO: Output variables list: [49, 46]
# INFO: Output variable: 49
# INFO: Variables list: [46, 47, 48, 49, 50]
# INFO: Output variables list: [49, 46]
# INFO: Output variable: 46
# INFO: [49, 46]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [46, 47, 48, 49, 50]
# INFO: [46, 47, 48, 49, 50]
# INFO: ['0', '0', '0', '0', '0']
# INFO: Variables list: [46, 47, 48, 49, 50]
# INFO: Output variables list: [49, 46]
# INFO: Output variable: 49
# INFO: Variables list: [46, 47, 48, 49, 50]
# INFO: Output variables list: [49, 46]
# INFO: Output variable: 46
# INFO: [49, 46]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# MESSAGE: the output signal is stable
# INFO: Index variable output signal: 63
# INFO: Output variables: [49, 46]
# {'11': '1', '10': '1', '01': '1', '00': '0'}
# INFO: Scene:  None
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [46, 47, 48, 49, 50]
# INFO: [46, 47, 48, 49, 50]
# INFO: ['1', '1', '1', '1', '1']
# INFO: Variables list: [46, 47, 48, 49, 50]
# INFO: Output variables list: [49, 46]
# INFO: Output variable: 49
# INFO: Variables list: [46, 47, 48, 49, 50]
# INFO: Output variables list: [49, 46]
# INFO: Output variable: 46
# INFO: [49, 46]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [46, 47, 48, 49, 50]
# INFO: [46, 47, 48, 49, 50]
# INFO: ['0', '0', '0', '0', '0']
# INFO: Variables list: [46, 47, 48, 49, 50]
# INFO: Output variables list: [49, 46]
# INFO: Output variable: 49
# INFO: Variables list: [46, 47, 48, 49, 50]
# INFO: Output variables list: [49, 46]
# INFO: Output variable: 46
# INFO: [49, 46]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# MESSAGE: the output signal is stable
# ===============================
# INFO: RESUME
# MESSAGE: The Local attractors are computed
# MESSAGE: NETWORK NUMBER :  9  PERMUTATION SIGNAL COUPLING:  None
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# INFO: Local Network: 9 Weight: 0
# INFO: Local network: 9
# INFO: Index variable output signal: 58
# INFO: Output variables: [45, 41]
# {'11': '1', '10': '1', '01': '1', '00': '0'}
# INFO: Scene:  None
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [41, 42, 43, 44, 45]
# INFO: [41, 42, 43, 44, 45]
# INFO: ['0', '0', '0', '0', '0']
# INFO: Variables list: [41, 42, 43, 44, 45]
# INFO: Output variables list: [45, 41]
# INFO: Output variable: 45
# INFO: Variables list: [41, 42, 43, 44, 45]
# INFO: Output variables list: [45, 41]
# INFO: Output variable: 41
# INFO: [45, 41]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [41, 42, 43, 44, 45]
# INFO: [41, 42, 43, 44, 45]
# INFO: ['1', '1', '1', '1', '1']
# INFO: Variables list: [41, 42, 43, 44, 45]
# INFO: Output variables list: [45, 41]
# INFO: Output variable: 45
# INFO: Variables list: [41, 42, 43, 44, 45]
# INFO: Output variables list: [45, 41]
# INFO: Output variable: 41
# INFO: [45, 41]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# MESSAGE: the output signal is stable
# INFO: Index variable output signal: 64
# INFO: Output variables: [45, 41]
# {'11': '1', '10': '1', '01': '1', '00': '0'}
# INFO: Scene:  None
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [41, 42, 43, 44, 45]
# INFO: [41, 42, 43, 44, 45]
# INFO: ['0', '0', '0', '0', '0']
# INFO: Variables list: [41, 42, 43, 44, 45]
# INFO: Output variables list: [45, 41]
# INFO: Output variable: 45
# INFO: Variables list: [41, 42, 43, 44, 45]
# INFO: Output variables list: [45, 41]
# INFO: Output variable: 41
# INFO: [45, 41]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [41, 42, 43, 44, 45]
# INFO: [41, 42, 43, 44, 45]
# INFO: ['1', '1', '1', '1', '1']
# INFO: Variables list: [41, 42, 43, 44, 45]
# INFO: Output variables list: [45, 41]
# INFO: Output variable: 45
# INFO: Variables list: [41, 42, 43, 44, 45]
# INFO: Output variables list: [45, 41]
# INFO: Output variable: 41
# INFO: [45, 41]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# MESSAGE: the output signal is stable
# ===============================
# INFO: RESUME
# MESSAGE: The Local attractors are computed
# MESSAGE: NETWORK NUMBER :  3  PERMUTATION SIGNAL COUPLING:  0
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  3  PERMUTATION SIGNAL COUPLING:  1
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# INFO: Local Network: 3 Weight: 2
# INFO: Local network: 3
# INFO: Index variable output signal: 52
# INFO: Output variables: [12, 14]
# {'11': '1', '10': '1', '01': '1', '00': '0'}
# INFO: Scene:  ('0',)
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [11, 12, 13, 14, 15, 63]
# INFO: [11, 12, 13, 14, 15]
# INFO: ['1', '0', '0', '0', '0', '0']
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [12, 14]
# INFO: Output variable: 12
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [12, 14]
# INFO: Output variable: 14
# INFO: [12, 14]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [11, 12, 13, 14, 15, 63]
# INFO: [11, 12, 13, 14, 15]
# INFO: ['0', '0', '0', '0', '0', '0']
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [12, 14]
# INFO: Output variable: 12
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [12, 14]
# INFO: Output variable: 14
# INFO: [12, 14]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [11, 12, 13, 14, 15, 63]
# INFO: [11, 12, 13, 14, 15]
# INFO: ['1', '1', '1', '1', '1', '0']
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [12, 14]
# INFO: Output variable: 12
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [12, 14]
# INFO: Output variable: 14
# INFO: [12, 14]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# INFO: Scene:  ('1',)
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [11, 12, 13, 14, 15, 63]
# INFO: [11, 12, 13, 14, 15]
# INFO: ['1', '0', '0', '0', '0', '1']
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [12, 14]
# INFO: Output variable: 12
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [12, 14]
# INFO: Output variable: 14
# INFO: [12, 14]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [11, 12, 13, 14, 15, 63]
# INFO: [11, 12, 13, 14, 15]
# INFO: ['1', '0', '1', '0', '0', '1']
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [12, 14]
# INFO: Output variable: 12
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [12, 14]
# INFO: Output variable: 14
# INFO: [12, 14]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [11, 12, 13, 14, 15, 63]
# INFO: [11, 12, 13, 14, 15]
# INFO: ['0', '0', '0', '0', '0', '1']
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [12, 14]
# INFO: Output variable: 12
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [12, 14]
# INFO: Output variable: 14
# INFO: [12, 14]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [11, 12, 13, 14, 15, 63]
# INFO: [11, 12, 13, 14, 15]
# INFO: ['0', '0', '1', '0', '0', '1']
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [12, 14]
# INFO: Output variable: 12
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [12, 14]
# INFO: Output variable: 14
# INFO: [12, 14]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [11, 12, 13, 14, 15, 63]
# INFO: [11, 12, 13, 14, 15]
# INFO: ['1', '1', '1', '1', '1', '1']
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [12, 14]
# INFO: Output variable: 12
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [12, 14]
# INFO: Output variable: 14
# INFO: [12, 14]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# MESSAGE: the output signal is stable
# INFO: Index variable output signal: 60
# INFO: Output variables: [15, 14]
# {'11': '1', '10': '1', '01': '1', '00': '0'}
# INFO: Scene:  ('0',)
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [11, 12, 13, 14, 15, 63]
# INFO: [11, 12, 13, 14, 15]
# INFO: ['1', '0', '0', '0', '0', '0']
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [15, 14]
# INFO: Output variable: 15
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [15, 14]
# INFO: Output variable: 14
# INFO: [15, 14]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [11, 12, 13, 14, 15, 63]
# INFO: [11, 12, 13, 14, 15]
# INFO: ['0', '0', '0', '0', '0', '0']
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [15, 14]
# INFO: Output variable: 15
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [15, 14]
# INFO: Output variable: 14
# INFO: [15, 14]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [11, 12, 13, 14, 15, 63]
# INFO: [11, 12, 13, 14, 15]
# INFO: ['1', '1', '1', '1', '1', '0']
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [15, 14]
# INFO: Output variable: 15
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [15, 14]
# INFO: Output variable: 14
# INFO: [15, 14]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# INFO: Scene:  ('1',)
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [11, 12, 13, 14, 15, 63]
# INFO: [11, 12, 13, 14, 15]
# INFO: ['1', '0', '0', '0', '0', '1']
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [15, 14]
# INFO: Output variable: 15
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [15, 14]
# INFO: Output variable: 14
# INFO: [15, 14]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [11, 12, 13, 14, 15, 63]
# INFO: [11, 12, 13, 14, 15]
# INFO: ['1', '0', '1', '0', '0', '1']
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [15, 14]
# INFO: Output variable: 15
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [15, 14]
# INFO: Output variable: 14
# INFO: [15, 14]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [11, 12, 13, 14, 15, 63]
# INFO: [11, 12, 13, 14, 15]
# INFO: ['0', '0', '0', '0', '0', '1']
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [15, 14]
# INFO: Output variable: 15
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [15, 14]
# INFO: Output variable: 14
# INFO: [15, 14]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [11, 12, 13, 14, 15, 63]
# INFO: [11, 12, 13, 14, 15]
# INFO: ['0', '0', '1', '0', '0', '1']
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [15, 14]
# INFO: Output variable: 15
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [15, 14]
# INFO: Output variable: 14
# INFO: [15, 14]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [11, 12, 13, 14, 15, 63]
# INFO: [11, 12, 13, 14, 15]
# INFO: ['1', '1', '1', '1', '1', '1']
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [15, 14]
# INFO: Output variable: 15
# INFO: Variables list: [11, 12, 13, 14, 15, 63]
# INFO: Output variables list: [15, 14]
# INFO: Output variable: 14
# INFO: [15, 14]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# MESSAGE: the output signal is stable
# ===============================
# INFO: RESUME
# INFO: Network 10
# INFO: Relation: 3 -> 10
# INFO: New weight: 0
# MESSAGE: The Local attractors are computed
# MESSAGE: NETWORK NUMBER :  4  PERMUTATION SIGNAL COUPLING:  0
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  4  PERMUTATION SIGNAL COUPLING:  1
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# INFO: Local Network: 4 Weight: 2
# INFO: Local network: 4
# INFO: Index variable output signal: 53
# INFO: Output variables: [18, 20]
# {'11': '1', '10': '1', '01': '1', '00': '0'}
# INFO: Scene:  ('0',)
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [16, 17, 18, 19, 20, 64]
# INFO: [16, 17, 18, 19, 20]
# INFO: ['1', '1', '1', '1', '1', '0']
# INFO: Variables list: [16, 17, 18, 19, 20, 64]
# INFO: Output variables list: [18, 20]
# INFO: Output variable: 18
# INFO: Variables list: [16, 17, 18, 19, 20, 64]
# INFO: Output variables list: [18, 20]
# INFO: Output variable: 20
# INFO: [18, 20]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [16, 17, 18, 19, 20, 64]
# INFO: [16, 17, 18, 19, 20]
# INFO: ['0', '0', '0', '0', '0', '0']
# INFO: Variables list: [16, 17, 18, 19, 20, 64]
# INFO: Output variables list: [18, 20]
# INFO: Output variable: 18
# INFO: Variables list: [16, 17, 18, 19, 20, 64]
# INFO: Output variables list: [18, 20]
# INFO: Output variable: 20
# INFO: [18, 20]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# INFO: Scene:  ('1',)
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [16, 17, 18, 19, 20, 64]
# INFO: [16, 17, 18, 19, 20]
# INFO: ['1', '1', '1', '1', '1', '1']
# INFO: Variables list: [16, 17, 18, 19, 20, 64]
# INFO: Output variables list: [18, 20]
# INFO: Output variable: 18
# INFO: Variables list: [16, 17, 18, 19, 20, 64]
# INFO: Output variables list: [18, 20]
# INFO: Output variable: 20
# INFO: [18, 20]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal is restricted
# MESSAGE: the output signal is stable
# ===============================
# INFO: RESUME
# INFO: Network 9
# INFO: Relation: 4 -> 9
# INFO: New weight: 0
# MESSAGE: The Local attractors are computed
# MESSAGE: NETWORK NUMBER :  5  PERMUTATION SIGNAL COUPLING:  0
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  5  PERMUTATION SIGNAL COUPLING:  1
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# INFO: Local Network: 5 Weight: 2
# INFO: Local network: 5
# INFO: Index variable output signal: 54
# INFO: Output variables: [22, 23]
# {'11': '1', '10': '1', '01': '1', '00': '0'}
# INFO: Scene:  ('0',)
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [21, 22, 23, 24, 25, 65]
# INFO: [21, 22, 23, 24, 25]
# INFO: ['0', '0', '0', '0', '0', '0']
# INFO: Variables list: [21, 22, 23, 24, 25, 65]
# INFO: Output variables list: [22, 23]
# INFO: Output variable: 22
# INFO: Variables list: [21, 22, 23, 24, 25, 65]
# INFO: Output variables list: [22, 23]
# INFO: Output variable: 23
# INFO: [22, 23]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [21, 22, 23, 24, 25, 65]
# INFO: [21, 22, 23, 24, 25]
# INFO: ['0', '0', '0', '0', '1', '0']
# INFO: Variables list: [21, 22, 23, 24, 25, 65]
# INFO: Output variables list: [22, 23]
# INFO: Output variable: 22
# INFO: Variables list: [21, 22, 23, 24, 25, 65]
# INFO: Output variables list: [22, 23]
# INFO: Output variable: 23
# INFO: [22, 23]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [21, 22, 23, 24, 25, 65]
# INFO: [21, 22, 23, 24, 25]
# INFO: ['1', '0', '0', '0', '1', '0']
# INFO: Variables list: [21, 22, 23, 24, 25, 65]
# INFO: Output variables list: [22, 23]
# INFO: Output variable: 22
# INFO: Variables list: [21, 22, 23, 24, 25, 65]
# INFO: Output variables list: [22, 23]
# INFO: Output variable: 23
# INFO: [22, 23]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [21, 22, 23, 24, 25, 65]
# INFO: [21, 22, 23, 24, 25]
# INFO: ['1', '0', '0', '1', '1', '0']
# INFO: Variables list: [21, 22, 23, 24, 25, 65]
# INFO: Output variables list: [22, 23]
# INFO: Output variable: 22
# INFO: Variables list: [21, 22, 23, 24, 25, 65]
# INFO: Output variables list: [22, 23]
# INFO: Output variable: 23
# INFO: [22, 23]
# INFO: 00
# INFO: Output value : 0
# INFO: STATE
# INFO: [21, 22, 23, 24, 25, 65]
# INFO: [21, 22, 23, 24, 25]
# INFO: ['1', '1', '0', '0', '1', '0']
# INFO: Variables list: [21, 22, 23, 24, 25, 65]
# INFO: Output variables list: [22, 23]
# INFO: Output variable: 22
# INFO: Variables list: [21, 22, 23, 24, 25, 65]
# INFO: Output variables list: [22, 23]
# INFO: Output variable: 23
# INFO: [22, 23]
# INFO: 10
# INFO: Output value : 1
# MESSAGE: the attractor signal is not stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [21, 22, 23, 24, 25, 65]
# INFO: [21, 22, 23, 24, 25]
# INFO: ['1', '1', '0', '1', '1', '0']
# INFO: Variables list: [21, 22, 23, 24, 25, 65]
# INFO: Output variables list: [22, 23]
# INFO: Output variable: 22
# INFO: Variables list: [21, 22, 23, 24, 25, 65]
# INFO: Output variables list: [22, 23]
# INFO: Output variable: 23
# INFO: [22, 23]
# INFO: 10
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# INFO: Scene:  ('1',)
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [21, 22, 23, 24, 25, 65]
# INFO: [21, 22, 23, 24, 25]
# INFO: ['1', '1', '1', '1', '1', '1']
# INFO: Variables list: [21, 22, 23, 24, 25, 65]
# INFO: Output variables list: [22, 23]
# INFO: Output variable: 22
# INFO: Variables list: [21, 22, 23, 24, 25, 65]
# INFO: Output variables list: [22, 23]
# INFO: Output variable: 23
# INFO: [22, 23]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal is restricted
# MESSAGE: the output signal is stable
# ===============================
# INFO: RESUME
# INFO: Network 6
# INFO: Relation: 5 -> 6
# INFO: New weight: 0
# MESSAGE: The Local attractors are computed
# MESSAGE: NETWORK NUMBER :  2  PERMUTATION SIGNAL COUPLING:  000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  2  PERMUTATION SIGNAL COUPLING:  001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  2  PERMUTATION SIGNAL COUPLING:  010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  2  PERMUTATION SIGNAL COUPLING:  011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  2  PERMUTATION SIGNAL COUPLING:  100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  2  PERMUTATION SIGNAL COUPLING:  101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  2  PERMUTATION SIGNAL COUPLING:  110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  2  PERMUTATION SIGNAL COUPLING:  111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# INFO: Local Network: 2 Weight: 6
# INFO: Local network: 2
# INFO: Index variable output signal: 51
# INFO: Output variables: [8, 9]
# {'11': '1', '10': '1', '01': '1', '00': '0'}
# INFO: Scene:  ('0', '0', '0')
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: [6, 7, 8, 9, 10]
# INFO: ['0', '0', '0', '0', '0', '0', '0', '0']
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 8
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 9
# INFO: [8, 9]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: [6, 7, 8, 9, 10]
# INFO: ['0', '0', '0', '0', '1', '0', '0', '0']
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 8
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 9
# INFO: [8, 9]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal is restricted
# INFO: Scene:  ('0', '0', '1')
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: [6, 7, 8, 9, 10]
# INFO: ['1', '0', '0', '0', '1', '0', '0', '1']
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 8
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 9
# INFO: [8, 9]
# INFO: 00
# INFO: Output value : 0
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: [6, 7, 8, 9, 10]
# INFO: ['1', '1', '1', '0', '1', '0', '0', '1']
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 8
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 9
# INFO: [8, 9]
# INFO: 10
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal value is stable
# INFO: Scene:  ('0', '1', '0')
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: [6, 7, 8, 9, 10]
# INFO: ['0', '1', '1', '1', '0', '0', '1', '0']
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 8
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 9
# INFO: [8, 9]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: [6, 7, 8, 9, 10]
# INFO: ['0', '1', '1', '1', '1', '0', '1', '0']
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 8
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 9
# INFO: [8, 9]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal is restricted
# INFO: Scene:  ('0', '1', '1')
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: [6, 7, 8, 9, 10]
# INFO: ['1', '1', '1', '1', '1', '0', '1', '1']
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 8
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 9
# INFO: [8, 9]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal is restricted
# INFO: Scene:  ('1', '0', '0')
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: [6, 7, 8, 9, 10]
# INFO: ['0', '0', '1', '1', '0', '1', '0', '0']
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 8
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 9
# INFO: [8, 9]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: [6, 7, 8, 9, 10]
# INFO: ['0', '0', '1', '1', '1', '1', '0', '0']
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 8
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 9
# INFO: [8, 9]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal is restricted
# INFO: Scene:  ('1', '0', '1')
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: [6, 7, 8, 9, 10]
# INFO: ['1', '1', '1', '1', '1', '1', '0', '1']
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 8
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 9
# INFO: [8, 9]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal is restricted
# INFO: Scene:  ('1', '1', '0')
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: [6, 7, 8, 9, 10]
# INFO: ['0', '1', '1', '1', '0', '1', '1', '0']
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 8
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 9
# INFO: [8, 9]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: [6, 7, 8, 9, 10]
# INFO: ['0', '1', '1', '1', '1', '1', '1', '0']
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 8
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 9
# INFO: [8, 9]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal is restricted
# INFO: Scene:  ('1', '1', '1')
# INFO: ATTRACTOR
# INFO: STATE
# INFO: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: [6, 7, 8, 9, 10]
# INFO: ['1', '1', '1', '1', '1', '1', '1', '1']
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 8
# INFO: Variables list: [6, 7, 8, 9, 10, 60, 61, 62]
# INFO: Output variables list: [8, 9]
# INFO: Output variable: 9
# INFO: [8, 9]
# INFO: 11
# INFO: Output value : 1
# MESSAGE: the attractor signal value is stable
# MESSAGE: the scene signal is restricted
# MESSAGE: the output signal is stable
# ===============================
# INFO: RESUME
# INFO: Network 3
# INFO: Relation: 2 -> 3
# INFO: New weight: 3
# INFO: Network 8
# INFO: Relation: 2 -> 8
# INFO: New weight: 0
# INFO: Network 10
# INFO: Relation: 2 -> 10
# INFO: New weight: 0
# MESSAGE: The Local attractors are computed
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000000000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000000001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000000010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000000011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000000100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000000101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000000110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000000111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000001000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000001001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000001010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000001011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000001100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000001101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000001110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000001111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000010000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000010001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000010010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000010011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000010100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000010101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000010110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000010111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000011000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000011001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000011010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000011011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000011100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000011101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000011110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000011111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000100000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000100001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000100010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000100011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000100100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000100101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000100110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000100111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000101000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000101001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000101010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000101011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000101100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000101101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000101110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000101111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000110000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000110001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000110010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000110011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000110100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000110101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000110110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000110111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000111000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000111001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000111010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000111011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000111100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000111101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  000111110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# ...
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110101111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110110000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110110001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110110010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110110011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110110100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110110101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110110110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110110111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110111000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110111001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110111010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110111011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110111100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110111101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110111110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  110111111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111000000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111000001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111000010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111000011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111000100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111000101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111000110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111000111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111001000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111001001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111001010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111001011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111001100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111001101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111001110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111001111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111010000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111010001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111010010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111010011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111010100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111010101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111010110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111010111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111011000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111011001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111011010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111011011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111011100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111011101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111011110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111011111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111100000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111100001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111100010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111100011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111100100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111100101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111100110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111100111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111101000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111101001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111101010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111101011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111101100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111101101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111101110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111101111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111110000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111110001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111110010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111110011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111110100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111110101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111110110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111110111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111111000
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111111001
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111111010
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111111011
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111111100
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111111101
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111111110
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# MESSAGE: NETWORK NUMBER :  1  PERMUTATION SIGNAL COUPLING:  111111111
# MESSAGE: BEGIN TO FIND ATTRACTORS
# MESSAGE: The expression cannot be satisfied
# MESSAGE: end find attractors
# INFO: Local Network: 1 Weight: 18
# INFO: Local network: 1
# ===============================
# INFO: RESUME
# INFO: Network 2
# INFO: Relation: 1 -> 2
# INFO: New weight: 9
# INFO: Network 3
# INFO: Relation: 1 -> 3
# INFO: New weight: 3
# INFO: Network 4
# INFO: Relation: 1 -> 4
# INFO: New weight: 3
# INFO: Network 5
# INFO: Relation: 1 -> 5
# INFO: New weight: 3
# INFO: Network 6
# INFO: Relation: 1 -> 6
# INFO: New weight: 0
# INFO: Network 7
# INFO: Relation: 1 -> 7
# INFO: New weight: 0
# INFO: Network 8
# INFO: Relation: 1 -> 8
# INFO: New weight: 0
# INFO: Network 9
# INFO: Relation: 1 -> 9
# INFO: New weight: 0
# INFO: Network 10
# INFO: Relation: 1 -> 10
# INFO: New weight: 0
# MESSAGE: The Local attractors are computed
# MESSAGE: ALL THE ATTRACTORS ARE COMPUTED
# ===============================
# FIND COMPATIBLE ATTRACTOR PAIRS
# END FIND ATTRACTOR PAIRS
# ==============================
# SHOW THE COUPLED SIGNALS KINDS
# SIGNAL: 51 RELATION: 2 -> 1 KIND: 3 - stable
# SIGNAL: 52 RELATION: 3 -> 1 KIND: 3 - stable
# SIGNAL: 53 RELATION: 4 -> 1 KIND: 3 - stable
# SIGNAL: 54 RELATION: 5 -> 1 KIND: 3 - stable
# SIGNAL: 55 RELATION: 6 -> 1 KIND: 3 - stable
# SIGNAL: 56 RELATION: 7 -> 1 KIND: 3 - stable
# SIGNAL: 57 RELATION: 8 -> 1 KIND: 3 - stable
# SIGNAL: 58 RELATION: 9 -> 1 KIND: 3 - stable
# SIGNAL: 59 RELATION: 10 -> 1 KIND: 3 - stable
# SIGNAL: 60 RELATION: 3 -> 2 KIND: 3 - stable
# SIGNAL: 61 RELATION: 8 -> 2 KIND: 3 - stable
# SIGNAL: 62 RELATION: 10 -> 2 KIND: 3 - stable
# SIGNAL: 63 RELATION: 10 -> 3 KIND: 3 - stable
# SIGNAL: 64 RELATION: 9 -> 4 KIND: 3 - stable
# SIGNAL: 65 RELATION: 6 -> 5 KIND: 3 - stable
