# %%
from classes.globaltopology import GlobalTopology

N_NODES = 6
N_EDGES = 6
V_TOPOLOGY = 2

o_CBNTopology = GlobalTopology(n_nodes=N_NODES, n_edges=N_EDGES, v_topology=V_TOPOLOGY)
o_CBNTopology.generate_networkx_graph()
o_CBNTopology.plot_topology()

# %%
o_CBNTopology.o_graph

# %%
o_global_topology_aux = GlobalTopology(n_nodes=N_NODES, n_edges=N_EDGES+1, v_topology=V_TOPOLOGY, o_graph=o_CBNTopology.o_graph)
o_global_topology_aux.generate_networkx_graph()
o_global_topology_aux.plot_topology()
# Out:
# entrouuuu
# [(1, 2), (2, 3), (2, 5), (3, 4), (3, 6), (7, 2)]
# [(1, 2), (2, 3), (2, 5), (3, 4), (3, 6), (7, 2), (0, 1)]
