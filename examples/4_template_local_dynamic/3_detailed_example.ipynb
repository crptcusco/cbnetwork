# %% [markdown]
# # CBN generation with Template for Local Dynamic

# %%
# internal imports
from classes.cbnetwork import CBN
from classes.globaltopology import GlobalTopology
from classes.localtemplates import LocalNetworkTemplate

# external imports

# Parameters
N_LOCAL_NETWORKS = 6
N_VARS_NETWORK = 5
V_TOPOLOGY = 2
N_EDGES = 10
N_INPUT_VARS = 2
N_OUTPUT_VARS = 2
N_MAX_CLAUSES = 2
N_MAX_LITERALS = 2

# %% [markdown]
# ## Generate the Global Topology

# %%
o_global_topology = GlobalTopology.generate_sample_topology(v_topology=V_TOPOLOGY,
                                                            n_nodes=N_LOCAL_NETWORKS,
                                                            n_edges=N_EDGES)

o_global_topology.plot_topology()

# %% [markdown]
# ## Generate the Local Network Template

# %%
o_template = LocalNetworkTemplate(v_topology=V_TOPOLOGY,
                                  n_vars_network=N_VARS_NETWORK,
                                  n_input_variables=N_INPUT_VARS,
                                  n_output_variables=N_OUTPUT_VARS,
                                  n_max_of_clauses=N_MAX_CLAUSES,
                                  n_max_of_literals=N_MAX_LITERALS)

o_template.show()
# Out:
# Local Network Template
# --------------------------------------------------------------------------------
# Local dynamic:
# 6 : [[-9, -8], [-8, -7]]
# 7 : [[11], [-10, -9], [-8, 10]]
# 8 : [[-8, 7], [10]]
# 9 : [[-11], [-7, 9], [-9, 8]]
# 10 : [[8], [-7]]
# Output variables for coupling signal: [5, 4]

# %% [markdown]
# ## Generate the CBN object

# %%
o_cbn = CBN.generate_cbn_from_template(v_topology=V_TOPOLOGY,
                                       n_local_networks=N_LOCAL_NETWORKS,
                                       n_vars_network=N_VARS_NETWORK,
                                       o_template=o_template,
                                       l_global_edges=o_global_topology.l_edges)

o_cbn.show_description()
# Out:
# --------------------------------------------------
# Local Network: 1
# --------------------------------------------------
# Local Variable index: 1
# Template Variable index: 6
# Template Function: [[-9, -8], [-8, -7]]
# Local Variable Index: 1
# CNF Function: [[-4, -3], [-3, -2]]
# --------------------------------------------------
# Local Variable index: 2
# Template Variable index: 7
# Template Function: [[11], [-10, -9], [-8, 10]]
# Local Variable Index: 2
# CNF Function: [[35], [-5, -4], [-3, 5]]
# --------------------------------------------------
# Local Variable index: 3
# Template Variable index: 8
# Template Function: [[-8, 7], [10]]
# Local Variable Index: 3
# CNF Function: [[-3, 2], [5]]
# --------------------------------------------------
# Local Variable index: 4
# Template Variable index: 9
# Template Function: [[-11], [-7, 9], [-9, 8]]
# Local Variable Index: 4
# CNF Function: [[35], [-2, 4], [-4, 3]]
# --------------------------------------------------
# Local Variable index: 5
# Template Variable index: 10
# Template Function: [[8], [-7]]
# Local Variable Index: 5
# CNF Function: [[3], [-2]]
# Local network created : 1
# --------------------------------------------------
# --------------------------------------------------
# Local Network: 2
# --------------------------------------------------
# Local Variable index: 6
# Template Variable index: 6
# Template Function: [[-9, -8], [-8, -7]]
# Local Variable Index: 6
# CNF Function: [[-9, -8], [-8, -7]]
# --------------------------------------------------
# Local Variable index: 7
# Template Variable index: 7
# Template Function: [[11], [-10, -9], [-8, 10]]
# Local Variable Index: 7
# CNF Function: [[36, 39], [-10, -9], [-8, 10]]
# --------------------------------------------------
# Local Variable index: 8
# Template Variable index: 8
# Template Function: [[-8, 7], [10]]
# Local Variable Index: 8
# CNF Function: [[-8, 7], [10]]
# --------------------------------------------------
# Local Variable index: 9
# Template Variable index: 9
# Template Function: [[-11], [-7, 9], [-9, 8]]
# Local Variable Index: 9
# CNF Function: [[36, 39], [-7, 9], [-9, 8]]
# --------------------------------------------------
# Local Variable index: 10
# Template Variable index: 10
# Template Function: [[8], [-7]]
# Local Variable Index: 10
# CNF Function: [[8], [-7]]
# Local network created : 2
# --------------------------------------------------
# --------------------------------------------------
# Local Network: 3
# --------------------------------------------------
# Local Variable index: 11
# Template Variable index: 6
# Template Function: [[-9, -8], [-8, -7]]
# Local Variable Index: 11
# CNF Function: [[-14, -13], [-13, -12]]
# --------------------------------------------------
# Local Variable index: 12
# Template Variable index: 7
# Template Function: [[11], [-10, -9], [-8, 10]]
# Local Variable Index: 12
# CNF Function: [[31], [-15, -14], [-13, 15]]
# --------------------------------------------------
# Local Variable index: 13
# Template Variable index: 8
# Template Function: [[-8, 7], [10]]
# Local Variable Index: 13
# CNF Function: [[-13, 12], [15]]
# --------------------------------------------------
# Local Variable index: 14
# Template Variable index: 9
# Template Function: [[-11], [-7, 9], [-9, 8]]
# Local Variable Index: 14
# CNF Function: [[31], [-12, 14], [-14, 13]]
# --------------------------------------------------
# Local Variable index: 15
# Template Variable index: 10
# Template Function: [[8], [-7]]
# Local Variable Index: 15
# CNF Function: [[13], [-12]]
# Local network created : 3
# --------------------------------------------------
# --------------------------------------------------
# Local Network: 4
# --------------------------------------------------
# Local Variable index: 16
# Template Variable index: 6
# Template Function: [[-9, -8], [-8, -7]]
# Local Variable Index: 16
# CNF Function: [[-19, -18], [-18, -17]]
# --------------------------------------------------
# Local Variable index: 17
# Template Variable index: 7
# Template Function: [[11], [-10, -9], [-8, 10]]
# Local Variable Index: 17
# CNF Function: [[33, 40], [-20, -19], [-18, 20]]
# --------------------------------------------------
# Local Variable index: 18
# Template Variable index: 8
# Template Function: [[-8, 7], [10]]
# Local Variable Index: 18
# CNF Function: [[-18, 17], [20]]
# --------------------------------------------------
# Local Variable index: 19
# Template Variable index: 9
# Template Function: [[-11], [-7, 9], [-9, 8]]
# Local Variable Index: 19
# CNF Function: [[33, 40], [-17, 19], [-19, 18]]
# --------------------------------------------------
# Local Variable index: 20
# Template Variable index: 10
# Template Function: [[8], [-7]]
# Local Variable Index: 20
# CNF Function: [[18], [-17]]
# Local network created : 4
# --------------------------------------------------
# --------------------------------------------------
# Local Network: 5
# --------------------------------------------------
# Local Variable index: 21
# Template Variable index: 6
# Template Function: [[-9, -8], [-8, -7]]
# Local Variable Index: 21
# CNF Function: [[-24, -23], [-23, -22]]
# --------------------------------------------------
# Local Variable index: 22
# Template Variable index: 7
# Template Function: [[11], [-10, -9], [-8, 10]]
# Local Variable Index: 22
# CNF Function: [[32, 38], [-25, -24], [-23, 25]]
# --------------------------------------------------
# Local Variable index: 23
# Template Variable index: 8
# Template Function: [[-8, 7], [10]]
# Local Variable Index: 23
# CNF Function: [[-23, 22], [25]]
# --------------------------------------------------
# Local Variable index: 24
# Template Variable index: 9
# Template Function: [[-11], [-7, 9], [-9, 8]]
# Local Variable Index: 24
# CNF Function: [[32, 38], [-22, 24], [-24, 23]]
# --------------------------------------------------
# Local Variable index: 25
# Template Variable index: 10
# Template Function: [[8], [-7]]
# Local Variable Index: 25
# CNF Function: [[23], [-22]]
# Local network created : 5
# --------------------------------------------------
# --------------------------------------------------
# Local Network: 6
# --------------------------------------------------
# Local Variable index: 26
# Template Variable index: 6
# Template Function: [[-9, -8], [-8, -7]]
# Local Variable Index: 26
# CNF Function: [[-29, -28], [-28, -27]]
# --------------------------------------------------
# Local Variable index: 27
# Template Variable index: 7
# Template Function: [[11], [-10, -9], [-8, 10]]
# Local Variable Index: 27
# CNF Function: [[34, 37], [-30, -29], [-28, 30]]
# --------------------------------------------------
# Local Variable index: 28
# Template Variable index: 8
# Template Function: [[-8, 7], [10]]
# Local Variable Index: 28
# CNF Function: [[-28, 27], [30]]
# --------------------------------------------------
# Local Variable index: 29
# Template Variable index: 9
# Template Function: [[-11], [-7, 9], [-9, 8]]
# Local Variable Index: 29
# CNF Function: [[34, 37], [-27, 29], [-29, 28]]
# --------------------------------------------------
# Local Variable index: 30
# Template Variable index: 10
# Template Function: [[8], [-7]]
# Local Variable Index: 30
# CNF Function: [[28], [-27]]
# Local network created : 6
# --------------------------------------------------
# **************************************************
# CBN DESCRIPTION
# ==================================================
# LOCAL NETWORKS: [1, 2, 3, 4, 5, 6]
# --------------------------------------------------
# Local Network: 1
# Internal Variables:  [1, 2, 3, 4, 5]
# External Variables:  [35]
# Total Variables:  [1, 2, 3, 4, 5, 35]
# Variable Index: 1 -> CNF :[[-4, -3], [-3, -2]]
# Variable Index: 2 -> CNF :[[35], [-5, -4], [-3, 5]]
# Variable Index: 3 -> CNF :[[-3, 2], [5]]
# Variable Index: 4 -> CNF :[[35], [-2, 4], [-4, 3]]
# Variable Index: 5 -> CNF :[[3], [-2]]
# --------------------------------------------------
# Local Network: 2
# Internal Variables:  [6, 7, 8, 9, 10]
# External Variables:  [36, 39]
# Total Variables:  [6, 7, 8, 9, 10, 36, 39]
# Variable Index: 6 -> CNF :[[-9, -8], [-8, -7]]
# Variable Index: 7 -> CNF :[[36, 39], [-10, -9], [-8, 10]]
# Variable Index: 8 -> CNF :[[-8, 7], [10]]
# Variable Index: 9 -> CNF :[[36, 39], [-7, 9], [-9, 8]]
# Variable Index: 10 -> CNF :[[8], [-7]]
# --------------------------------------------------
# Local Network: 3
# Internal Variables:  [11, 12, 13, 14, 15]
# External Variables:  [31]
# Total Variables:  [11, 12, 13, 14, 15, 31]
# Variable Index: 11 -> CNF :[[-14, -13], [-13, -12]]
# Variable Index: 12 -> CNF :[[31], [-15, -14], [-13, 15]]
# Variable Index: 13 -> CNF :[[-13, 12], [15]]
# Variable Index: 14 -> CNF :[[31], [-12, 14], [-14, 13]]
# Variable Index: 15 -> CNF :[[13], [-12]]
# --------------------------------------------------
# Local Network: 4
# Internal Variables:  [16, 17, 18, 19, 20]
# External Variables:  [33, 40]
# Total Variables:  [16, 17, 18, 19, 20, 33, 40]
# Variable Index: 16 -> CNF :[[-19, -18], [-18, -17]]
# Variable Index: 17 -> CNF :[[33, 40], [-20, -19], [-18, 20]]
# Variable Index: 18 -> CNF :[[-18, 17], [20]]
# Variable Index: 19 -> CNF :[[33, 40], [-17, 19], [-19, 18]]
# Variable Index: 20 -> CNF :[[18], [-17]]
# --------------------------------------------------
# Local Network: 5
# Internal Variables:  [21, 22, 23, 24, 25]
# External Variables:  [32, 38]
# Total Variables:  [21, 22, 23, 24, 25, 32, 38]
# Variable Index: 21 -> CNF :[[-24, -23], [-23, -22]]
# Variable Index: 22 -> CNF :[[32, 38], [-25, -24], [-23, 25]]
# Variable Index: 23 -> CNF :[[-23, 22], [25]]
# Variable Index: 24 -> CNF :[[32, 38], [-22, 24], [-24, 23]]
# Variable Index: 25 -> CNF :[[23], [-22]]
# --------------------------------------------------
# Local Network: 6
# Internal Variables:  [26, 27, 28, 29, 30]
# External Variables:  [34, 37]
# Total Variables:  [26, 27, 28, 29, 30, 34, 37]
# Variable Index: 26 -> CNF :[[-29, -28], [-28, -27]]
# Variable Index: 27 -> CNF :[[34, 37], [-30, -29], [-28, 30]]
# Variable Index: 28 -> CNF :[[-28, 27], [30]]
# Variable Index: 29 -> CNF :[[34, 37], [-27, 29], [-29, 28]]
# Variable Index: 30 -> CNF :[[28], [-27]]
# ==================================================
# DIRECTED EDGES: [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ## Find Stable Attractor Fields

# %%
o_cbn.find_local_attractors_sequential()
# o_cbn.show_attractors()

o_cbn.find_compatible_pairs()
# o_cbn.show_attractor_pairs()

o_cbn.mount_stable_attractor_fields()
# o_cbn.show_attractors_fields()
# Out:
# **************************************************
# FIND LOCAL ATTRACTORS
# --------------------------------------------------
# FIND ATTRACTORS FOR NETWORK: 1
# --------------------------------------------------
# Network: 1  Local Scene: 0
# end find attractors
# --------------------------------------------------
# Network: 1  Local Scene: 1
# end find attractors
# INFO:  the output signal is restricted
# INFO:  the output signal is restricted
# --------------------------------------------------
# FIND ATTRACTORS FOR NETWORK: 2
# --------------------------------------------------
# Network: 2  Local Scene: 00
# end find attractors
# --------------------------------------------------
# Network: 2  Local Scene: 01
# end find attractors
# --------------------------------------------------
# Network: 2  Local Scene: 10
# end find attractors
# --------------------------------------------------
# Network: 2  Local Scene: 11
# end find attractors
# INFO:  the output signal is restricted
# INFO:  the output signal is restricted
# INFO:  the output signal is restricted
# --------------------------------------------------
# FIND ATTRACTORS FOR NETWORK: 3
# --------------------------------------------------
# Network: 3  Local Scene: 0
# end find attractors
# --------------------------------------------------
# Network: 3  Local Scene: 1
# end find attractors
# INFO:  the output signal is restricted
# INFO:  the output signal is restricted
# --------------------------------------------------
# FIND ATTRACTORS FOR NETWORK: 4
# --------------------------------------------------
# Network: 4  Local Scene: 00
# end find attractors
# --------------------------------------------------
# Network: 4  Local Scene: 01
# end find attractors
# --------------------------------------------------
# Network: 4  Local Scene: 10
# end find attractors
# --------------------------------------------------
# Network: 4  Local Scene: 11
# end find attractors
# INFO:  the output signal is restricted
# INFO:  the output signal is restricted
# --------------------------------------------------
# FIND ATTRACTORS FOR NETWORK: 5
# --------------------------------------------------
# Network: 5  Local Scene: 00
# end find attractors
# --------------------------------------------------
# Network: 5  Local Scene: 01
# end find attractors
# --------------------------------------------------
# Network: 5  Local Scene: 10
# end find attractors
# --------------------------------------------------
# Network: 5  Local Scene: 11
# end find attractors
# --------------------------------------------------
# FIND ATTRACTORS FOR NETWORK: 6
# --------------------------------------------------
# Network: 6  Local Scene: 00
# end find attractors
# --------------------------------------------------
# Network: 6  Local Scene: 01
# end find attractors
# --------------------------------------------------
# Network: 6  Local Scene: 10
# end find attractors
# --------------------------------------------------
# Network: 6  Local Scene: 11
# end find attractors
# INFO:  the output signal is restricted
# Number of local attractors: 41
# --------------------------------------------------
# END FIND LOCAL ATTRACTORS
# **************************************************
# FIND COMPATIBLE ATTRACTOR PAIRS
# Number of attractor pairs: 116
# --------------------------------------------------
# END FIND ATTRACTOR PAIRS
# **************************************************
# FIND ATTRACTOR FIELDS
# Number of attractor fields found: 2
# --------------------------------------------------
# END MOUNT ATTRACTOR FIELDS

# %%
# show kind of coupling signals
o_cbn.show_coupled_signals_kind()
# Out:
# =================================================
# SHOW THE COUPLED SIGNALS KINDS
# SIGNAL: 31 RELATION: 2 -> 3 KIND: 1 - RESTRICTED
# SIGNAL: 32 RELATION: 2 -> 5 KIND: 1 - RESTRICTED
# SIGNAL: 33 RELATION: 2 -> 4 KIND: 1 - RESTRICTED
# SIGNAL: 34 RELATION: 3 -> 6 KIND: 1 - RESTRICTED
# SIGNAL: 35 RELATION: 3 -> 1 KIND: 1 - RESTRICTED
# SIGNAL: 36 RELATION: 4 -> 2 KIND: 1 - RESTRICTED
# SIGNAL: 37 RELATION: 4 -> 6 KIND: 1 - RESTRICTED
# SIGNAL: 38 RELATION: 6 -> 5 KIND: 1 - RESTRICTED
# SIGNAL: 39 RELATION: 1 -> 2 KIND: 1 - RESTRICTED
# SIGNAL: 40 RELATION: 1 -> 4 KIND: 1 - RESTRICTED
# Number of restricted signals : 10
